# %% [markdown]
# # Training phase
#
# ## Setting up the configuration
# Fisrt let's check the configuration parameters in case you want to change some of them base on the previous analysis. In any case the default configuration should **provide you with a good start**.

# %%
from planktonclass import config

config.print_conf_table()
# Out:
# group                    key                           value
# ===========================================================================
# augmentation             train_mode                    {'h_flip': 0.5, 'v_flip': 0.5, 'rot': 0.7, 'rot_lim': 90, 'stretch': 0.0, 'crop': 1.0, 'zoom': 0.2, 'blur': 0.3, 'pixel_noise': 0.3, 'pixel_sat': 0.3, 'cutout': 0.5}
#
# augmentation             use_augmentation              True
#
# augmentation             val_mode                      {'h_flip': 0.0, 'v_flip': 0.0, 'rot': 0.0, 'rot_lim': 0, 'stretch': 0.0, 'crop': 1.0, 'zoom': 0.0, 'blur': 0.0, 'pixel_noise': 0.0, 'pixel_sat': 0.0, 'cutout': 0.0}
#
# ---------------------------------------------------------------------------
#
# dataset                  mean_RGB                      None
#
# dataset                  split_ratios                  [0.8, 0.1, 0.1]
#
# dataset                  std_RGB                       None
#
# ---------------------------------------------------------------------------
#
# general                  base_directory                .
#
# general                  images_directory              ../../flowcyto_ecotaxa//OBSEA//sorted_images
#
# ---------------------------------------------------------------------------
#
# model                    image_size                    100
#
# model                    modelname                     EfficientNetV2B0
#
# model                    num_classes                   None
#
# model                    preprocess_mode               None
#
# ---------------------------------------------------------------------------
#
# monitor                  use_remote                    False
#
# monitor                  use_tensorboard               False
#
# ---------------------------------------------------------------------------
#
# testing                  ckpt_name                     final_model.h5
#
# testing                  output_directory              None
#
# testing                  timestamp                     None
#
# ---------------------------------------------------------------------------
#
# training                 batch_size                    16
#
# training                 ckpt_freq                     None
#
# training                 epochs                        15
#
# training                 initial_lr                    0.001
#
# training                 l2_reg                        0.0001
#
# training                 lr_schedule_mode              step
#
# training                 lr_step_decay                 0.1
#
# training                 lr_step_schedule              [0.7, 0.9]
#
# training                 mode                          normal
#
# training                 use_class_weights             False
#
# training                 use_early_stopping            False
#
# training                 use_multiprocessing           False
#
# training                 use_test                      True
#
# training                 use_validation                True
#
# ---------------------------------------------------------------------------

# %% [markdown]
# In case you want to change the configuration feel free to do so by modifying `etc/config.yaml`.

# %% [markdown]
# ## Training
#
# Once you have set up the configuration if needed you can launch the training by running the file `train_runfile.py`

# %%
# Navigate to the directory containing the script
import os

# if os.path.isdir('/srv/phyto-plankton-classification/planktonclass/'):
#     os.chdir('/srv/phyto-plankton-classification/planktonclass/')
#     print("Changed directory to /srv/phyto-plankton-classification/planktonclass/")
# elif os.path.isdir('../planktonclass/'):
os.chdir('../planktonclass/')
print("Changed directory to ../planktonclass/")
# Run the script
# %run train_runfile.py --workers 1
# Out:
# Changed directory to ../planktonclass/
# 2026-03-23 11:34:03 - planktonclass.utils - INFO - [utils] Created 8 dataset directories
# 2026-03-23 11:34:03 - planktonclass.train_runfile - INFO - [train] Writing run log to: ../models/2026-03-23_113403/logs/training.log
# 2026-03-23 11:34:03 - planktonclass.train_runfile - INFO - [train] Preparing dataset splits
# 2026-03-23 11:34:03 - planktonclass.train_runfile - INFO - [train] Split ratios: [0.8, 0.1, 0.1]
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Scanning images in ['flowcyto_ecotaxa', 'OBSEA', 'sorted_images']
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Split counts | train: 1306 | val: 185 | test: 154
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Writing 1306 entries to train.txt
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Writing 154 entries to test.txt
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Writing 185 entries to val.txt
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Writing 22 class names
# 2026-03-23 11:34:03 - planktonclass.train_runfile - INFO - [train] Loading training data
# 2026-03-23 11:34:03 - planktonclass.train_runfile - INFO - [train] Splits directory: ../models/2026-03-23_113403/dataset_files
# 2026-03-23 11:34:03 - planktonclass.train_runfile - INFO - [train] Images directory: ../../../flowcyto_ecotaxa/OBSEA/sorted_images
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Loading train split
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Loading val split
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Loading class names
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Loading aphia IDs
# 2026-03-23 11:34:03 - planktonclass.train_runfile - INFO - [train] Computing dataset statistics
# 2026-03-23 11:34:03 - planktonclass.data_utils - INFO - [data] Computing RGB statistics for 1306 images
# 2026-03-23 11:34:19 - planktonclass.data_utils - INFO - [data] Computing RGB statistics: 100%|##########| 1306/1306 [00:16<00:00, 81.37img/s]
# 2026-03-23 11:34:19 - planktonclass.data_utils - INFO - [data] Mean RGB pixel: [159.28943139540524, 159.28943139540524, 159.28943139540524]
# 2026-03-23 11:34:19 - planktonclass.data_utils - INFO - [data] RGB standard deviation: [17.248096358477902, 17.248096358477902, 17.248096358477902]
# 2026-03-23 11:34:19 - planktonclass.train_runfile - INFO - [train] Building model
# 2026-03-23 11:34:21 - planktonclass.train_runfile - INFO - [train] Starting training
# 2026-03-23 11:34:21 - planktonclass.train_runfile - INFO - [train] Epochs: 15 | Batch size: 16 | Training samples: 1306 | Validation samples: 185
# 2026-03-23 11:34:21 - planktonclass.utils - INFO - [train] Epoch metrics will be written to training.log and epoch_metrics.csv.
# 2026-03-23 11:34:21 - planktonclass.train_runfile - INFO - [train] Epoch 1/15
# 2026-03-23 11:35:21 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 60s 251ms/step - accuracy: 0.5054 - loss: 1.7997 - val_accuracy: 0.0649 - val_loss: 2.9373 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:35:21 - planktonclass.train_runfile - INFO - [train] Epoch 2/15
# 2026-03-23 11:35:42 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 259ms/step - accuracy: 0.6217 - loss: 1.2775 - val_accuracy: 0.1676 - val_loss: 3.3686 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:35:42 - planktonclass.train_runfile - INFO - [train] Epoch 3/15
# 2026-03-23 11:36:03 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 21s 258ms/step - accuracy: 0.6761 - loss: 1.1284 - val_accuracy: 0.3081 - val_loss: 2.9917 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:36:03 - planktonclass.train_runfile - INFO - [train] Epoch 4/15
# 2026-03-23 11:36:23 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 236ms/step - accuracy: 0.7060 - loss: 1.0074 - val_accuracy: 0.0703 - val_loss: 2.8185 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:36:23 - planktonclass.train_runfile - INFO - [train] Epoch 5/15
# 2026-03-23 11:36:44 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 263ms/step - accuracy: 0.7259 - loss: 0.9295 - val_accuracy: 0.1730 - val_loss: 2.8846 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:36:44 - planktonclass.train_runfile - INFO - [train] Epoch 6/15
# 2026-03-23 11:37:04 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 238ms/step - accuracy: 0.7435 - loss: 0.8247 - val_accuracy: 0.5514 - val_loss: 1.4972 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:37:04 - planktonclass.train_runfile - INFO - [train] Epoch 7/15
# 2026-03-23 11:37:24 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 243ms/step - accuracy: 0.7534 - loss: 0.8070 - val_accuracy: 0.6216 - val_loss: 1.4225 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:37:24 - planktonclass.train_runfile - INFO - [train] Epoch 8/15
# 2026-03-23 11:37:44 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - accuracy: 0.7726 - loss: 0.7871 - val_accuracy: 0.0703 - val_loss: 3.1154 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:37:44 - planktonclass.train_runfile - INFO - [train] Epoch 9/15
# 2026-03-23 11:38:05 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 246ms/step - accuracy: 0.7833 - loss: 0.7189 - val_accuracy: 0.2216 - val_loss: 2.8350 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:38:05 - planktonclass.train_runfile - INFO - [train] Epoch 10/15
# 2026-03-23 11:38:25 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 242ms/step - accuracy: 0.7649 - loss: 0.7303 - val_accuracy: 0.1730 - val_loss: 2.7973 - lr: 0.0010 - learning_rate: 0.0010
# 2026-03-23 11:38:25 - planktonclass.utils - INFO - ▌ Learning rate decayed to: 1.00e-04
# 2026-03-23 11:38:25 - planktonclass.utils - INFO - [train] Learning rate decayed to: 1.00e-04
# 2026-03-23 11:38:25 - planktonclass.train_runfile - INFO - [train] Epoch 11/15
# 2026-03-23 11:38:45 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 242ms/step - accuracy: 0.8170 - loss: 0.6263 - val_accuracy: 0.8541 - val_loss: 0.5052 - lr: 1.0000e-04 - learning_rate: 1.0000e-04
# 2026-03-23 11:38:45 - planktonclass.train_runfile - INFO - [train] Epoch 12/15
# 2026-03-23 11:39:05 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 242ms/step - accuracy: 0.8461 - loss: 0.5345 - val_accuracy: 0.8216 - val_loss: 0.6140 - lr: 1.0000e-04 - learning_rate: 1.0000e-04
# 2026-03-23 11:39:05 - planktonclass.train_runfile - INFO - [train] Epoch 13/15
# 2026-03-23 11:39:23 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 19s 228ms/step - accuracy: 0.8637 - loss: 0.4380 - val_accuracy: 0.7892 - val_loss: 0.7869 - lr: 1.0000e-04 - learning_rate: 1.0000e-04
# 2026-03-23 11:39:23 - planktonclass.utils - INFO - ▌ Learning rate decayed to: 1.00e-05
# 2026-03-23 11:39:23 - planktonclass.utils - INFO - [train] Learning rate decayed to: 1.00e-05
# 2026-03-23 11:39:23 - planktonclass.train_runfile - INFO - [train] Epoch 14/15
# 2026-03-23 11:39:43 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 19s 235ms/step - accuracy: 0.8522 - loss: 0.4675 - val_accuracy: 0.8703 - val_loss: 0.5349 - lr: 1.0000e-05 - learning_rate: 1.0000e-05
# 2026-03-23 11:39:43 - planktonclass.train_runfile - INFO - [train] Epoch 15/15
# 2026-03-23 11:40:03 - planktonclass.train_runfile - INFO - [train] 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 244ms/step - accuracy: 0.8591 - loss: 0.4384 - val_accuracy: 0.8757 - val_loss: 0.4932 - lr: 1.0000e-05 - learning_rate: 1.0000e-05
# 2026-03-23 11:40:03 - planktonclass.train_runfile - INFO - [train] Training complete
# 2026-03-23 11:40:03 - planktonclass.train_runfile - INFO - [train] Saving to: ../models/2026-03-23_113403
# 2026-03-23 11:40:03 - planktonclass.train_runfile - INFO - [train] Saving training statistics
# 2026-03-23 11:40:03 - planktonclass.train_runfile - INFO - [train] Saving configuration
# 2026-03-23 11:40:03 - planktonclass.train_runfile - INFO - [train] Saving model in HDF5 format
# 2026-03-23 11:40:04 - planktonclass.train_runfile - INFO - [train] Training finished successfully.
# 2026-03-23 11:40:04 - planktonclass.train_runfile - INFO - [train] Evaluating test split
# 2026-03-23 11:40:04 - planktonclass.data_utils - INFO - [data] Loading test split
# 2026-03-23 11:40:14 - planktonclass.train_runfile - INFO - [train] 154/154 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step
# 2026-03-23 11:40:15 - planktonclass.train_runfile - INFO - [train] Predictions saved to: ../models/2026-03-23_113403/predictions/final_model.h5+DS_split+top5.json
# 2026-03-23 11:40:15 - planktonclass.train_runfile - INFO - [train] Test set evaluation completed.

# %% [markdown]
# #### Tips:
# * Running a python file is also done by
#     1. opening a terminal
#     2. typing: `cd phyto-plankton-classification/planktonclass` and then `python train_runfile.py` (or directly `python phyto-plankton-classification/planktonclass/train_runfile.py`)
# * If you are running several times different training configurations but with the **same** dataset you might consider to add the `mean_RGB` and `std_RGB` parameters to your `config.yaml` file. You can find them computed in any of your already trained models by looking into `../models/[timestamp]/conf/conf.txt`.

# %% [markdown]
# ## Visualizing the training results

# %% [markdown]
# ### Display a single timestamp

# %%
import os
import json
from datetime import timedelta

import matplotlib.pylab as plt
import numpy as np

from planktonclass import paths, plot_utils
from datetime import datetime

timestamp = datetime.now().strftime('%Y-%m-%d_%H:%M:%S')
TIMESTAMP = timestamp
# User parameters to set
TIMESTAMP = 'cyto_model'                       # timestamp of the model

# Set the timestamp
paths.timestamp = TIMESTAMP

# Load training statistics
stats_path = os.path.join(paths.get_stats_dir(), 'stats.json')
with open(stats_path) as f:
    stats = json.load(f)

# Load training configuration
conf_path = os.path.join(paths.get_conf_dir(), 'conf.json')
with open(conf_path) as f:
    conf = json.load(f)

# Plot the trainig plots 
plot_utils.training_plots(conf, stats)

# Print total training time
tr_time = int(stats['training time (s)'])
print('Total training time: {}'.format(timedelta(seconds=tr_time)))
# Out:
# Total training time: 0:11:34
